# %% [markdown]
# Experiment E1-10:
# - binary classification
# - dataset train 3500, val 1500
# - BATCH_SIZE = 20
# - IMAGE_SIZE = 512
# - EPOCHS = 30
# - criterion = nn.BCEWithLogitsLoss()
# - optimizer = Adam
# - lr=1e-5
# - augmentation
#
# model:
# - self.base_model(x)
# - unfreeze 3 layers
# - self.globalavg(x) # (2,2)
# - self.flatten(x)
# - self.fc(x) # (5120,512)->Dropout(0.5)->Relu->(512,1)

# %%
import numpy as np
import os
import sys
import glob
import pandas as pd
import cv2
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
from torch.utils.data.dataloader import DataLoader
from torchvision import transforms, models
import torchvision
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix

from PIL import Image

# %%
# load common py
sys.path.append('../src')
import config
import common_utils
import data_utils
import train_utils
import plot_utils

# %%
# override config for experiment
EXP_CODE = "E1-10"
SAVE_FILENAME = f"stage1-{EXP_CODE}-metrics"

config.EPOCHS = 30
config.LEARNING_RATE = 1e-5
config.IMAGE_SIZE = 512

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

common_utils.set_seed(config.SEED)

# %%
df = pd.read_csv(config.TRAIN_CSV)

# %%
# split data into train, val, test 70/15/15
# for fast training, use only 3500 and 1500 samples for train and val

train_df, val_df, test_df, train_small_df, val_small_df = data_utils.split_data(df, config.SEED, small_train_size=3500, small_val_size=1500)

# %%
# create transforms
train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.4),
    transforms.RandomVerticalFlip(p=0.4),
    transforms.Resize((config.IMAGE_SIZE, config.IMAGE_SIZE)),   
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

test_val_transform = transforms.Compose([
    transforms.Resize((config.IMAGE_SIZE, config.IMAGE_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# %%
# create datasets
train_small_dataset = data_utils.SteelDataset(df=train_small_df, 
                                    data_folder=config.IMAGE_FOLDER,
                                    transforms=train_transform,
                                    image_size=config.IMAGE_SIZE,
                                    return_tensor=True
                                    )
val_small_dataset = data_utils.SteelDataset(df=val_small_df, 
                                    data_folder=config.IMAGE_FOLDER,
                                    transforms=test_val_transform,
                                    image_size=config.IMAGE_SIZE,
                                    return_tensor=True
                                   )

# %%
train_small_loader = DataLoader(train_small_dataset, batch_size=config.BATCH_SIZE,
                          shuffle=True,
                          num_workers=config.NUM_WORKERS, pin_memory=True, persistent_workers=True, prefetch_factor=config.PREFETCH_FACTOR
                          )

val_small_loader = DataLoader(val_small_dataset, batch_size=config.BATCH_SIZE,
                         shuffle=False,
                         num_workers=config.NUM_WORKERS, pin_memory=True, persistent_workers=True, prefetch_factor=config.PREFETCH_FACTOR
                         )

# %%
# create model
class SteelModel(nn.Module):
    def __init__(self):
        super(SteelModel, self).__init__()

        self.base_model = models.mobilenet_v2(weights='IMAGENET1K_V1').features
        for param in self.base_model.parameters():
            param.requires_grad = False

        for p in self.base_model[-3:].parameters():
            p.requires_grad = True

        # Remove original classifier
        #self.base_model.classifier = nn.Identity()

        self.globalavg = nn.AdaptiveAvgPool2d((2, 2))

        self.flatten = nn.Flatten()
        self.fc = nn.Sequential(
            nn.Linear(1280 * 2 * 2, 512),
            nn.Dropout(0.5),
            nn.ReLU(),
            nn.Linear(512, 1),
        )
               

    def forward(self, x):
        x = self.base_model(x)
        #print(x.shape)
        x = self.globalavg(x)
        #print(x.shape)
        x = self.flatten(x)
        #print(x.shape)
        x = self.fc(x)
        #print(x.shape)
        return x

# %%
model = SteelModel()
model = model.to(device)
criterion = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=config.LEARNING_RATE)

# %%
# %%time

arr_train_acc = []
arr_train_loss = []
arr_train_precision = []
arr_train_recall = []
arr_train_f1 = []
arr_train_rocauc = []
arr_train_conf_matrix = []

arr_val_acc = []
arr_val_loss = []
arr_val_precision = []
arr_val_recall = []
arr_val_f1 = []
arr_val_rocauc = []
arr_val_conf_matrix = []

idx = 0
for epoch in range(config.EPOCHS):
    train_loss, train_all_labels, train_all_preds, train_all_probs = train_utils.train_one_epoch(model, train_small_loader, criterion, optimizer, device)
    val_loss, val_all_labels, val_all_preds, val_all_probs = train_utils.validate_one_epoch(model, val_small_loader, criterion, device)

    # train metrics
    train_accuracy = (train_all_preds == train_all_labels).mean()
    train_precision = precision_score(train_all_labels, train_all_preds)
    train_recall = recall_score(train_all_labels, train_all_preds)
    train_f1 = f1_score(train_all_labels, train_all_preds)
    train_rocauc = roc_auc_score(train_all_labels, train_all_probs)
    train_conf_matrix = confusion_matrix(train_all_labels, train_all_preds)
    train_tn, train_fp, train_fn, train_tp = train_conf_matrix.ravel()
    
    arr_train_loss.append(train_loss)
    arr_train_acc.append(train_accuracy)
    arr_train_precision.append(train_precision)
    arr_train_recall.append(train_recall)
    arr_train_f1.append(train_f1)
    arr_train_rocauc.append(train_rocauc)
    arr_train_conf_matrix.append({'tn': train_tn, 'fp': train_fp, 'fn': train_fn, 'tp': train_tp})

    # val metrics
    val_accuracy = (val_all_preds == val_all_labels).mean()
    val_precision = precision_score(val_all_labels, val_all_preds)
    val_recall = recall_score(val_all_labels, val_all_preds)
    val_f1 = f1_score(val_all_labels, val_all_preds)
    val_rocauc = roc_auc_score(val_all_labels, val_all_probs)
    val_conf_matrix = confusion_matrix(val_all_labels, val_all_preds)
    val_tn, val_fp, val_fn, val_tp = val_conf_matrix.ravel()

    arr_val_loss.append(val_loss)
    arr_val_acc.append(val_accuracy)
    arr_val_precision.append(val_precision)
    arr_val_recall.append(val_recall)
    arr_val_f1.append(val_f1)
    arr_val_rocauc.append(val_rocauc)
    arr_val_conf_matrix.append({'tn': val_tn, 'fp': val_fp, 'fn': val_fn, 'tp': val_tp})

    print(idx+1)
    print(f"Epoch {epoch+1}/{config.EPOCHS}")
    print(f"  Train Loss: {train_loss:.4f} | Train Acc: {train_accuracy:.4f}")
    print(f"  Val Loss  : {val_loss:.4f} | Val Acc: {val_accuracy:.4f}")
    print(f"  Train Precision: {train_precision:.4f} | Recall: {train_recall:.4f} | F1: {train_f1:.4f} | ROC AUC: {train_rocauc:.4f}")
    print(f"  Train Confusion Matrix: TN={train_tn}, FP={train_fp}, FN={train_fn}, TP={train_tp}")
    print(f"  Val Precision: {val_precision:.4f} | Recall: {val_recall:.4f} | F1: {val_f1:.4f} | ROC AUC: {val_rocauc:.4f}")
    print(f"  Val Confusion Matrix: TN={val_tn}, FP={val_fp}, FN={val_fn}, TP={val_tp}")

    idx += 1
    #break
# Out:
# 1
# Epoch 1/20
#   Train Loss: 0.4753 | Train Acc: 0.7597
#   Val Loss  : 0.3532 | Val Acc: 0.8607
#   Train Precision: 0.7662 | Recall: 0.8059 | F1: 0.7855 | ROC AUC: 0.8493
#   Train Confusion Matrix: TN=1119, FP=470, FN=371, TP=1540
#   Val Precision: 0.8344 | Recall: 0.9292 | F1: 0.8793 | ROC AUC: 0.9322
#   Val Confusion Matrix: TN=530, FP=151, FN=58, TP=761
# 2
# Epoch 2/20
#   Train Loss: 0.3407 | Train Acc: 0.8491
#   Val Loss  : 0.3167 | Val Acc: 0.8760
#   Train Precision: 0.8484 | Recall: 0.8812 | F1: 0.8645 | ROC AUC: 0.9320
#   Train Confusion Matrix: TN=1288, FP=301, FN=227, TP=1684
#   Val Precision: 0.8846 | Recall: 0.8889 | F1: 0.8867 | ROC AUC: 0.9400
#   Val Confusion Matrix: TN=586, FP=95, FN=91, TP=728
# 3
# Epoch 3/20
#   Train Loss: 0.2915 | Train Acc: 0.8820
#   Val Loss  : 0.3124 | Val Acc: 0.8680
#   Train Precision: 0.8802 | Recall: 0.9074 | F1: 0.8936 | ROC AUC: 0.9520
#   Train Confusion Matrix: TN=1353, FP=236, FN=177, TP=1734
#   Val Precision: 0.8454 | Recall: 0.9280 | F1: 0.8847 | ROC AUC: 0.9437
#   Val Confusion Matrix: TN=542, FP=139, FN=59, TP=760
# 4
# Epoch 4/20
#   Train Loss: 0.2588 | Train Acc: 0.9009
#   Val Loss  : 0.2922 | Val Acc: 0.8847
#   Train Precision: 0.9014 | Recall: 0.9189 | F1: 0.9101 | ROC AUC: 0.9630
#   Train Confusion Matrix: TN=1397, FP=192, FN=155, TP=1756
#   Val Precision: 0.8818 | Recall: 0.9109 | F1: 0.8961 | ROC AUC: 0.9489
#   Val Confusion Matrix: TN=581, FP=100, FN=73, TP=746
# 5
# Epoch 5/20
#   Train Loss: 0.2437 | Train Acc: 0.9111
#   Val Loss  : 0.2927 | Val Acc: 0.8833
#   Train Precision: 0.9141 | Recall: 0.9241 | F1: 0.9191 | ROC AUC: 0.9674
#   Train Confusion Matrix: TN=1423, FP=166, FN=145, TP=1766
#   Val Precision: 0.9271 | Recall: 0.8535 | F1: 0.8887 | ROC AUC: 0.9521
#   Val Confusion Matrix: TN=626, FP=55, FN=120, TP=699
# 6
# Epoch 6/20
#   Train Loss: 0.2345 | Train Acc: 0.9091
#   Val Loss  : 0.2881 | Val Acc: 0.8833
#   Train Precision: 0.9125 | Recall: 0.9220 | F1: 0.9172 | ROC AUC: 0.9695
#   Train Confusion Matrix: TN=1420, FP=169, FN=149, TP=1762
#   Val Precision: 0.8917 | Recall: 0.8950 | F1: 0.8934 | ROC AUC: 0.9479
#   Val Confusion Matrix: TN=592, FP=89, FN=86, TP=733
# 7
# Epoch 7/20
#   Train Loss: 0.2206 | Train Acc: 0.9137
#   Val Loss  : 0.2810 | Val Acc: 0.8827
#   Train Precision: 0.9184 | Recall: 0.9241 | F1: 0.9212 | ROC AUC: 0.9735
#   Train Confusion Matrix: TN=1432, FP=157, FN=145, TP=1766
#   Val Precision: 0.9096 | Recall: 0.8718 | F1: 0.8903 | ROC AUC: 0.9535
#   Val Confusion Matrix: TN=610, FP=71, FN=105, TP=714
# 8
# Epoch 8/20
#   Train Loss: 0.2053 | Train Acc: 0.9234
#   Val Loss  : 0.2701 | Val Acc: 0.8887
#   Train Precision: 0.9272 | Recall: 0.9330 | F1: 0.9301 | ROC AUC: 0.9779
#   Train Confusion Matrix: TN=1449, FP=140, FN=128, TP=1783
#   Val Precision: 0.8966 | Recall: 0.8999 | F1: 0.8982 | ROC AUC: 0.9553
#   Val Confusion Matrix: TN=596, FP=85, FN=82, TP=737
# 9
# Epoch 9/20
#   Train Loss: 0.2039 | Train Acc: 0.9266
#   Val Loss  : 0.2766 | Val Acc: 0.8853
#   Train Precision: 0.9285 | Recall: 0.9377 | F1: 0.9331 | ROC AUC: 0.9777
#   Train Confusion Matrix: TN=1451, FP=138, FN=119, TP=1792
#   Val Precision: 0.9079 | Recall: 0.8791 | F1: 0.8933 | ROC AUC: 0.9538
#   Val Confusion Matrix: TN=608, FP=73, FN=99, TP=720
# 10
# Epoch 10/20
#   Train Loss: 0.1836 | Train Acc: 0.9369
#   Val Loss  : 0.2756 | Val Acc: 0.8900
#   Train Precision: 0.9387 | Recall: 0.9461 | F1: 0.9424 | ROC AUC: 0.9834
#   Train Confusion Matrix: TN=1471, FP=118, FN=103, TP=1808
#   Val Precision: 0.8699 | Recall: 0.9389 | F1: 0.9031 | ROC AUC: 0.9560
#   Val Confusion Matrix: TN=566, FP=115, FN=50, TP=769
# 11
# Epoch 11/20
#   Train Loss: 0.1846 | Train Acc: 0.9366
#   Val Loss  : 0.2736 | Val Acc: 0.8900
#   Train Precision: 0.9346 | Recall: 0.9503 | F1: 0.9424 | ROC AUC: 0.9825
#   Train Confusion Matrix: TN=1462, FP=127, FN=95, TP=1816
#   Val Precision: 0.9214 | Recall: 0.8730 | F1: 0.8966 | ROC AUC: 0.9565
#   Val Confusion Matrix: TN=620, FP=61, FN=104, TP=715
# 12
# Epoch 12/20
#   Train Loss: 0.1789 | Train Acc: 0.9337
#   Val Loss  : 0.2686 | Val Acc: 0.8973
#   Train Precision: 0.9347 | Recall: 0.9445 | F1: 0.9396 | ROC AUC: 0.9837
#   Train Confusion Matrix: TN=1463, FP=126, FN=106, TP=1805
#   Val Precision: 0.9130 | Recall: 0.8974 | F1: 0.9052 | ROC AUC: 0.9560
#   Val Confusion Matrix: TN=611, FP=70, FN=84, TP=735
# 13
# Epoch 13/20
#   Train Loss: 0.1707 | Train Acc: 0.9389
#   Val Loss  : 0.2694 | Val Acc: 0.8900
#   Train Precision: 0.9435 | Recall: 0.9445 | F1: 0.9440 | ROC AUC: 0.9856
#   Train Confusion Matrix: TN=1481, FP=108, FN=106, TP=1805
#   Val Precision: 0.8811 | Recall: 0.9231 | F1: 0.9016 | ROC AUC: 0.9554
#   Val Confusion Matrix: TN=579, FP=102, FN=63, TP=756
# 14
# Epoch 14/20
#   Train Loss: 0.1582 | Train Acc: 0.9460
#   Val Loss  : 0.2674 | Val Acc: 0.8973
#   Train Precision: 0.9466 | Recall: 0.9550 | F1: 0.9508 | ROC AUC: 0.9890
#   Train Confusion Matrix: TN=1486, FP=103, FN=86, TP=1825
#   Val Precision: 0.8862 | Recall: 0.9316 | F1: 0.9083 | ROC AUC: 0.9567
#   Val Confusion Matrix: TN=583, FP=98, FN=56, TP=763
# 15
# Epoch 15/20
#   Train Loss: 0.1592 | Train Acc: 0.9420
#   Val Loss  : 0.2716 | Val Acc: 0.8940
#   Train Precision: 0.9439 | Recall: 0.9503 | F1: 0.9471 | ROC AUC: 0.9884
#   Train Confusion Matrix: TN=1481, FP=108, FN=95, TP=1816
#   Val Precision: 0.9015 | Recall: 0.9048 | F1: 0.9031 | ROC AUC: 0.9542
#   Val Confusion Matrix: TN=600, FP=81, FN=78, TP=741
# 16
# Epoch 16/20
#   Train Loss: 0.1565 | Train Acc: 0.9463
#   Val Loss  : 0.2667 | Val Acc: 0.9000
#   Train Precision: 0.9471 | Recall: 0.9550 | F1: 0.9510 | ROC AUC: 0.9882
#   Train Confusion Matrix: TN=1487, FP=102, FN=86, TP=1825
#   Val Precision: 0.9114 | Recall: 0.9048 | F1: 0.9081 | ROC AUC: 0.9563
#   Val Confusion Matrix: TN=609, FP=72, FN=78, TP=741
# 17
# Epoch 17/20
#   Train Loss: 0.1500 | Train Acc: 0.9514
#   Val Loss  : 0.2600 | Val Acc: 0.9000
#   Train Precision: 0.9503 | Recall: 0.9613 | F1: 0.9558 | ROC AUC: 0.9898
#   Train Confusion Matrix: TN=1493, FP=96, FN=74, TP=1837
#   Val Precision: 0.8977 | Recall: 0.9219 | F1: 0.9096 | ROC AUC: 0.9583
#   Val Confusion Matrix: TN=595, FP=86, FN=64, TP=755
# 18
# Epoch 18/20
#   Train Loss: 0.1429 | Train Acc: 0.9560
#   Val Loss  : 0.2595 | Val Acc: 0.9007
#   Train Precision: 0.9545 | Recall: 0.9655 | F1: 0.9599 | ROC AUC: 0.9912
#   Train Confusion Matrix: TN=1501, FP=88, FN=66, TP=1845
#   Val Precision: 0.9066 | Recall: 0.9121 | F1: 0.9093 | ROC AUC: 0.9581
#   Val Confusion Matrix: TN=604, FP=77, FN=72, TP=747
# 19
# Epoch 19/20
#   Train Loss: 0.1427 | Train Acc: 0.9560
#   Val Loss  : 0.2651 | Val Acc: 0.8980
#   Train Precision: 0.9564 | Recall: 0.9634 | F1: 0.9599 | ROC AUC: 0.9911
#   Train Confusion Matrix: TN=1505, FP=84, FN=70, TP=1841
#   Val Precision: 0.9132 | Recall: 0.8987 | F1: 0.9058 | ROC AUC: 0.9567
#   Val Confusion Matrix: TN=611, FP=70, FN=83, TP=736
# 20
# Epoch 20/20
#   Train Loss: 0.1424 | Train Acc: 0.9554
#   Val Loss  : 0.2655 | Val Acc: 0.9033
#   Train Precision: 0.9526 | Recall: 0.9665 | F1: 0.9595 | ROC AUC: 0.9909
#   Train Confusion Matrix: TN=1497, FP=92, FN=64, TP=1847
#   Val Precision: 0.9050 | Recall: 0.9194 | F1: 0.9122 | ROC AUC: 0.9561
#   Val Confusion Matrix: TN=602, FP=79, FN=66, TP=753
# CPU times: user 1min 33s, sys: 34.1 s, total: 2min 7s
# Wall time: 3min 5s

# %%
df_metrics = train_utils.build_metric_df(
    arr_train_loss, arr_train_acc, arr_train_precision, arr_train_recall, 
    arr_train_f1, arr_train_rocauc, arr_train_conf_matrix,
    arr_val_loss, arr_val_acc, arr_val_precision, arr_val_recall, 
    arr_val_f1, arr_val_rocauc, arr_val_conf_matrix
)

# %%
df_metrics
# Out:
#     train_loss  train_acc  train_precision  train_recall  train_f1  \
# 0     0.475344   0.759714         0.766169      0.805861  0.785514
# 1     0.340662   0.849143         0.848363      0.881214  0.864476
# 2     0.291495   0.882000         0.880203      0.907378  0.893584
# 3     0.258811   0.900857         0.901437      0.918891  0.910080
# 4     0.243660   0.911143         0.914079      0.924123  0.919074
# 5     0.234518   0.909143         0.912481      0.922030  0.917231
# 6     0.220570   0.913714         0.918357      0.924123  0.921231
# 7     0.205280   0.923429         0.927197      0.933019  0.930099
# 8     0.203929   0.926571         0.928497      0.937729  0.933090
# 9     0.183638   0.936857         0.938733      0.946102  0.942403
# 10    0.184562   0.936571         0.934637      0.950288  0.942398
# 11    0.178900   0.933714         0.934749      0.944532  0.939615
# 12    0.170722   0.938857         0.943544      0.944532  0.944038
# 13    0.158191   0.946000         0.946577      0.954997  0.950768
# 14    0.159206   0.942000         0.943867      0.950288  0.947066
# 15    0.156457   0.946286         0.947068      0.954997  0.951016
# 16    0.150047   0.951429         0.950336      0.961277  0.955775
# 17    0.142934   0.956000         0.954475      0.965463  0.959938
# 18    0.142729   0.956000         0.956364      0.963370  0.959854
# 19    0.142361   0.955429         0.952553      0.966510  0.959481
#
#     train_rocauc                               train_conf_matrix  val_loss  \
# 0       0.849316  {'tn': 1119, 'fp': 470, 'fn': 371, 'tp': 1540}  0.353186
# 1       0.932031  {'tn': 1288, 'fp': 301, 'fn': 227, 'tp': 1684}  0.316734
# 2       0.951970  {'tn': 1353, 'fp': 236, 'fn': 177, 'tp': 1734}  0.312439
# 3       0.962994  {'tn': 1397, 'fp': 192, 'fn': 155, 'tp': 1756}  0.292243
# 4       0.967401  {'tn': 1423, 'fp': 166, 'fn': 145, 'tp': 1766}  0.292719
# 5       0.969468  {'tn': 1420, 'fp': 169, 'fn': 149, 'tp': 1762}  0.288139
# 6       0.973501  {'tn': 1432, 'fp': 157, 'fn': 145, 'tp': 1766}  0.280974
# 7       0.977945  {'tn': 1449, 'fp': 140, 'fn': 128, 'tp': 1783}  0.270062
# 8       0.977689  {'tn': 1451, 'fp': 138, 'fn': 119, 'tp': 1792}  0.276571
# 9       0.983372  {'tn': 1471, 'fp': 118, 'fn': 103, 'tp': 1808}  0.275620
# 10      0.982533   {'tn': 1462, 'fp': 127, 'fn': 95, 'tp': 1816}  0.273646
# 11      0.983692  {'tn': 1463, 'fp': 126, 'fn': 106, 'tp': 1805}  0.268604
# 12      0.985625  {'tn': 1481, 'fp': 108, 'fn': 106, 'tp': 1805}  0.269362
# 13      0.989018   {'tn': 1486, 'fp': 103, 'fn': 86, 'tp': 1825}  0.267356
# 14      0.988368   {'tn': 1481, 'fp': 108, 'fn': 95, 'tp': 1816}  0.271584
# 15      0.988170   {'tn': 1487, 'fp': 102, 'fn': 86, 'tp': 1825}  0.266704
# 16      0.989769    {'tn': 1493, 'fp': 96, 'fn': 74, 'tp': 1837}  0.259973
# 17      0.991202    {'tn': 1501, 'fp': 88, 'fn': 66, 'tp': 1845}  0.259510
# 18      0.991082    {'tn': 1505, 'fp': 84, 'fn': 70, 'tp': 1841}  0.265083
# 19      0.990925    {'tn': 1497, 'fp': 92, 'fn': 64, 'tp': 1847}  0.265468
#
#      val_acc  val_precision  val_recall    val_f1  val_rocauc  \
# 0   0.860667       0.834430    0.929182  0.879261    0.932228
# 1   0.876000       0.884569    0.888889  0.886724    0.940026
# 2   0.868000       0.845384    0.927961  0.884750    0.943739
# 3   0.884667       0.881797    0.910867  0.896096    0.948931
# 4   0.883333       0.927056    0.853480  0.888748    0.952065
# 5   0.883333       0.891727    0.894994  0.893358    0.947922
# 6   0.882667       0.909554    0.871795  0.890274    0.953462
# 7   0.888667       0.896594    0.899878  0.898233    0.955336
# 8   0.885333       0.907945    0.879121  0.893300    0.953808
# 9   0.890000       0.869910    0.938950  0.903112    0.956000
# 10  0.890000       0.921392    0.873016  0.896552    0.956537
# 11  0.897333       0.913043    0.897436  0.905172    0.955953
# 12  0.890000       0.881119    0.923077  0.901610    0.955431
# 13  0.897333       0.886179    0.931624  0.908333    0.956680
# 14  0.894000       0.901460    0.904762  0.903108    0.954192
# 15  0.900000       0.911439    0.904762  0.908088    0.956275
# 16  0.900000       0.897741    0.921856  0.909639    0.958341
# 17  0.900667       0.906553    0.912088  0.909312    0.958149
# 18  0.898000       0.913151    0.898657  0.905846    0.956720
# 19  0.903333       0.905048    0.919414  0.912174    0.956123
#
#                                 val_conf_matrix
# 0   {'tn': 530, 'fp': 151, 'fn': 58, 'tp': 761}
# 1    {'tn': 586, 'fp': 95, 'fn': 91, 'tp': 728}
# 2   {'tn': 542, 'fp': 139, 'fn': 59, 'tp': 760}
# 3   {'tn': 581, 'fp': 100, 'fn': 73, 'tp': 746}
# 4   {'tn': 626, 'fp': 55, 'fn': 120, 'tp': 699}
# 5    {'tn': 592, 'fp': 89, 'fn': 86, 'tp': 733}
# 6   {'tn': 610, 'fp': 71, 'fn': 105, 'tp': 714}
# 7    {'tn': 596, 'fp': 85, 'fn': 82, 'tp': 737}
# 8    {'tn': 608, 'fp': 73, 'fn': 99, 'tp': 720}
# 9   {'tn': 566, 'fp': 115, 'fn': 50, 'tp': 769}
# 10  {'tn': 620, 'fp': 61, 'fn': 104, 'tp': 715}
# 11   {'tn': 611, 'fp': 70, 'fn': 84, 'tp': 735}
# 12  {'tn': 579, 'fp': 102, 'fn': 63, 'tp': 756}
# 13   {'tn': 583, 'fp': 98, 'fn': 56, 'tp': 763}
# 14   {'tn': 600, 'fp': 81, 'fn': 78, 'tp': 741}
# 15   {'tn': 609, 'fp': 72, 'fn': 78, 'tp': 741}
# 16   {'tn': 595, 'fp': 86, 'fn': 64, 'tp': 755}
# 17   {'tn': 604, 'fp': 77, 'fn': 72, 'tp': 747}
# 18   {'tn': 611, 'fp': 70, 'fn': 83, 'tp': 736}
# 19   {'tn': 602, 'fp': 79, 'fn': 66, 'tp': 753}

# %%
print('Val Metrics:')
print(df_metrics[config.VAL_METRICS])
print('')
print('Val Confusion Matrix:')
print(df_metrics[config.VAL_CF])

# %%
df_metrics.describe()
# Out:
#        train_loss  train_acc  train_precision  train_recall   train_f1  \
# count   20.000000  20.000000        20.000000     20.000000  20.000000
# mean     0.212201   0.918743         0.919984      0.932836   0.926337
# std      0.081914   0.046209         0.045177      0.036923   0.041087
# min      0.142361   0.759714         0.766169      0.805861   0.785514
# 25%      0.157758   0.910643         0.913679      0.923600   0.918613
# 50%      0.184100   0.935143         0.934693      0.944532   0.941006
# 75%      0.236804   0.946071         0.946700      0.954997   0.950830
# max      0.475344   0.956000         0.956364      0.966510   0.959938
#
#        train_rocauc   val_loss    val_acc  val_precision  val_recall  \
# count     20.000000  20.000000  20.000000      20.000000   20.000000
# mean       0.971303   0.281299   0.888667       0.894304    0.904090
# std        0.032450   0.023145   0.011189       0.023653    0.022703
# min        0.849316   0.259510   0.860667       0.834430    0.853480
# 25%        0.968951   0.267193   0.883333       0.883876    0.893468
# 50%        0.982953   0.272615   0.890000       0.899600    0.904762
# 75%        0.988530   0.289165   0.897500       0.910025    0.922161
# max        0.991202   0.353186   0.903333       0.927056    0.938950
#
#           val_f1  val_rocauc
# count  20.000000   20.000000
# mean    0.898684    0.952396
# std     0.009432    0.006760
# min     0.879261    0.932228
# 25%     0.892544    0.951282
# 50%     0.899921    0.955383
# 75%     0.906407    0.956341
# max     0.912174    0.958341

# %%
print(df_metrics.describe())
# Out:
#        train_loss  train_acc  train_precision  train_recall   train_f1  \
# count   20.000000  20.000000        20.000000     20.000000  20.000000
# mean     0.212201   0.918743         0.919984      0.932836   0.926337
# std      0.081914   0.046209         0.045177      0.036923   0.041087
# min      0.142361   0.759714         0.766169      0.805861   0.785514
# 25%      0.157758   0.910643         0.913679      0.923600   0.918613
# 50%      0.184100   0.935143         0.934693      0.944532   0.941006
# 75%      0.236804   0.946071         0.946700      0.954997   0.950830
# max      0.475344   0.956000         0.956364      0.966510   0.959938
#
#        train_rocauc   val_loss    val_acc  val_precision  val_recall  \
# count     20.000000  20.000000  20.000000      20.000000   20.000000
# mean       0.971303   0.281299   0.888667       0.894304    0.904090
# std        0.032450   0.023145   0.011189       0.023653    0.022703
# min        0.849316   0.259510   0.860667       0.834430    0.853480
# 25%        0.968951   0.267193   0.883333       0.883876    0.893468
# 50%        0.982953   0.272615   0.890000       0.899600    0.904762
# 75%        0.988530   0.289165   0.897500       0.910025    0.922161
# max        0.991202   0.353186   0.903333       0.927056    0.938950
#
#           val_f1  val_rocauc
# count  20.000000   20.000000
# mean    0.898684    0.952396
# std     0.009432    0.006760
# min     0.879261    0.932228
# 25%     0.892544    0.951282
# 50%     0.899921    0.955383
# 75%     0.906407    0.956341
# max     0.912174    0.958341

# %%
plot_utils.plot_train_val_metrics(df_metrics, exp_code=EXP_CODE, save_path=SAVE_FILENAME+".png")

# %%
df_train_conf_matrix = df_metrics['train_conf_matrix'].apply(lambda x: pd.Series([x['tn'], x['fp'], x['fn'], x['tp']]))
df_val_conf_matrix = df_metrics['val_conf_matrix'].apply(lambda x: pd.Series([x['tn'], x['fp'], x['fn'], x['tp']]))
#df_metrics[['val_tn', 'val_fp', 'val_fn', 'val_tp']]
df_train_conf_matrix.columns = ['train_tn', 'train_fp', 'train_fn', 'train_tp']
df_val_conf_matrix.columns = ['val_tn', 'val_fp', 'val_fn', 'val_tp']

# %%
df_train_conf_matrix.describe()
# Out:
#           train_tn    train_fp   train_fn    train_tp
# count    20.000000   20.000000   20.00000    20.00000
# mean   1432.950000  156.050000  128.35000  1782.65000
# std      91.533414   91.533414   70.56037    70.56037
# min    1119.000000   84.000000   64.00000  1540.00000
# 25%    1422.250000  102.750000   86.00000  1765.00000
# 50%    1462.500000  126.500000  106.00000  1805.00000
# 75%    1486.250000  166.750000  146.00000  1825.00000
# max    1505.000000  470.000000  371.00000  1847.00000

# %%
df_val_conf_matrix.describe()
# Out:
#            val_tn      val_fp      val_fn      val_tp
# count   20.000000   20.000000   20.000000   20.000000
# mean   592.550000   88.450000   78.550000  740.450000
# std     24.370981   24.370981   18.593929   18.593929
# min    530.000000   55.000000   50.000000  699.000000
# 25%    582.500000   71.750000   63.750000  731.750000
# 50%    598.000000   83.000000   78.000000  741.000000
# 75%    609.250000   98.500000   87.250000  755.250000
# max    626.000000  151.000000  120.000000  769.000000

# %%
df_metrics.to_csv(SAVE_FILENAME+".csv", index=False)
